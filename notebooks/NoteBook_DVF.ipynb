# %%
import pandas as pd

df = pd.read_csv('dvf.csv.gz', compression='gzip', low_memory=False)
print(f"Nombre de transactions initial : {len(df):,}")
# Out:
# Nombre de transactions initial : 20,133,668

# %%
df
# Out:
#            id_mutation date_mutation  numero_disposition nature_mutation  \
# 0               2020-1    2020-01-07                   1           Vente
# 1               2020-2    2020-01-02                   1           Vente
# 2               2020-2    2020-01-02                   1           Vente
# 3               2020-2    2020-01-02                   1           Vente
# 4               2020-2    2020-01-02                   1           Vente
# ...                ...           ...                 ...             ...
# 20133663  2024-1218061    2024-11-28                   1           Vente
# 20133664  2024-1218061    2024-11-28                   1           Vente
# 20133665  2024-1218061    2024-11-28                   1           Vente
# 20133666  2024-1218061    2024-11-28                   1           Vente
# 20133667  2024-1218061    2024-11-28                   1           Vente
#
#           valeur_fonciere  adresse_numero adresse_suffixe  \
# ...
